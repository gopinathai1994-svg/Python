# %%
from exportFunction import dataExport
dataExport.mrgFunction()
# Out:
# enter the gender : male
# enter the age : 67
# Your Gender: male
# Your Age: 67
# NOT ELIGIBLE

# %%
dataExport.fieldList()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
dataExport.triangle()
# Out:
# Height: 32
# Breadth: 34
# Area formula: (Height*Breadth)/2
# Area of Triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10

# %%
dataExport.OddEven()
# Out:
# Enter a number:  67
# 67 is Odd number
# 67

# %%
dataExport.percentage()
# Out:
# Total : 468
# Percentage : 93.60000000000001
