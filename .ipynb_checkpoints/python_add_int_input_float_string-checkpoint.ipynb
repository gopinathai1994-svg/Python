# %%
print("print1");
# Out:
# print1

# %%
num1=2
num2=5
result= num1+num2
print(result)
# Out:
# 7

# %%
data1= int(input("Enter the number : "))
data2= int(input("Enter the number : "))
resultInput = data1+data2
subMultipleInput = (data1 - data2) * 3
print("Result : " , resultInput)
print("multiple method:" , subMultipleInput)
# Out:
# Enter the number :  30
# Enter the number :  10
# Result :  40
# multiple method: 60

# %%
data3 = float(input("enter some value :"))
# Out:
# enter some value : 6.7

# %%
data4 = input('ente the name : ')
# Out:
# ente the name :  value data
