# %%
num1 =10
num2 =30
if(num1 < num2):
    print("num2 is grater")
else:
    print("num1 is grater")
# Out:
# num2 is grater

# %%
data1 = int(input("Enter the first number: "))
data2 = int(input("Enter the second number: "))
data3 = int(input("Enter the third number: "))


if (data1 < data2 & data2 > data3):
    print("Second data is greater than both first and third.")
elif (data2 < data3):
    print("Third value is higher than second.")
else:
    print("Default result: Neither condition was met.")
# Out:
# Enter the first number:  80
# Enter the second number:  30
# Enter the third number:  59
# Third value is higher than second.

# %%
movie = int(input('enter the hit movie:'))

if(movie < 18):
    print('vali')
elif(movie < 35):
    print('gilly')
elif(movie < 56):
    print('billa')
else:
    print('citizan')
# Out:
# enter the hit movie: 56
# citizan

# %%
lists = [34,32,45,56,78,12]
for temp in lists:
    if(50 <= temp):
        print("grater then equal value is :",temp)
    else:
        print("lesser the value is :",temp)

        
for list in lists:
    if((list % 2) == 0):
        print('the valus is zero of :' ,list)
    else:
        print('not a zero', list)
# Out:
# lesser the value is : 34
# lesser the value is : 32
# lesser the value is : 45
# grater then equal value is : 56
# grater then equal value is : 78
# lesser the value is : 12
# the valus is zero of : 34
# the valus is zero of : 32
# not a zero 45
# the valus is zero of : 56
# the valus is zero of : 78
# the valus is zero of : 12

# %%
# Division

# %%
a = 76
b = 31
print("answer : ", a/b)
# Out:
# answer :  2.4516129032258065

# %%
#Floor division Quotient
a= 33
b = 5
print('floor division :' , a // b)
# Out:
# floor division : 6

# %%
#Modulo reminder
a= 30
b = 7 
print('module ', a % b)
# Out:
# module  2

# %%
#power
a = 5
b = 3
print ('power' , pow(a,b))
# Out:
# power 125

# %%
lengthvalue = [34,32,45,56,78,12]
print('length of :',len(lengthvalue))
# Out:
# length of : 6

# %%
import random

# Generate a random secret number between 1 and 100
secret_number = random.randint(1, 100)


for attempt in range(0, 7):
    guess = int(
        input(f"Attempt {attempt} of 7 - Guess a number between 1 and 100: ")
    )

    if guess == secret_number:
        print("🎉 Correct! You guessed the number!")
        break 
    elif guess < secret_number:
        print("Too low! Try a higher number.\n")
    else:
        print("Too high! Try a lower number.\n")
else:
    print(f"❌ Game over! You ran out of attempts. The number was {secret_number}.")
# Out:
# Attempt 0 of 7 - Guess a number between 1 and 100:  30
# Too high! Try a lower number.
# Attempt 1 of 7 - Guess a number between 1 and 100:  12
# Too low! Try a higher number.
# Attempt 2 of 7 - Guess a number between 1 and 100:  25
# Too high! Try a lower number.
# Attempt 3 of 7 - Guess a number between 1 and 100:  20
# Too high! Try a lower number.
# Attempt 4 of 7 - Guess a number between 1 and 100:  15
# Too high! Try a lower number.
# Attempt 5 of 7 - Guess a number between 1 and 100:  13
# Too low! Try a higher number.
# Attempt 6 of 7 - Guess a number between 1 and 100:  14
# 🎉 Correct! You guessed the number!
